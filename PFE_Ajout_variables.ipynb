# %%
import pandas as pd
import sqlite3
pd.options.display.max_columns = 205
import warnings
warnings.filterwarnings("ignore")

# %%
FinalStatcon = sqlite3.connect('finalstat.sqlite')

# %%
FinalStat = pd.read_sql("""SELECT * from FinalStat""", FinalStatcon)

# %%
DF = FinalStat.copy()

# %%
#Récupérations des index des MVPS de chaque année
index_mvps = DF.sort_values('Share',ascending=False).drop_duplicates('Year',keep='first').index 
DF[DF.index.isin(index_mvps)]
del DF["level_0"]

# %% [markdown]
# ## Création des colonnes "MVP l'année précédente" et "MVP deux années avant"

# %% [markdown]
# Maintenant que nous avons récupérer tous les MVPS, on peut maintenant créer nos 2 colonnes. Pour se faire, nous allons travailler sur un sous ensemble de nos données qui contient uniquement les informations qui nous intéressent dans cette partie.

# %%
temp = DF.loc[index_mvps,["Player","Year"]].sort_values("Year")
temp["MVP"] = 1

temp
# Out:
#                       Player  Year  MVP
# 12155           Moses Malone  1982    1
# 12156           Moses Malone  1983    1
# 10083             Larry Bird  1984    1
# 10084             Larry Bird  1985    1
# 10085             Larry Bird  1986    1
# 10649          Magic Johnson  1987    1
# 11617         Michael Jordan  1988    1
# 10651          Magic Johnson  1989    1
# 10652          Magic Johnson  1990    1
# 11620         Michael Jordan  1991    1
# 11621         Michael Jordan  1992    1
# 2471         Charles Barkley  1993    1
# 6416         Hakeem Olajuwon  1994    1
# 4006          David Robinson  1995    1
# 11624         Michael Jordan  1996    1
# 9091             Karl Malone  1997    1
# 11626         Michael Jordan  1998    1
# 9093             Karl Malone  1999    1
# 14783       Shaquille O'Neal  2000    1
# 385            Allen Iverson  2001    1
# 15715             Tim Duncan  2002    1
# 15716             Tim Duncan  2003    1
# 9513           Kevin Garnett  2004    1
# 15258             Steve Nash  2005    1
# 15259             Steve Nash  2006    1
# 4684           Dirk Nowitzki  2007    1
# 9760             Kobe Bryant  2008    1
# 10243           LeBron James  2009    1
# 10244           LeBron James  2010    1
# 4482            Derrick Rose  2011    1
# 10246           LeBron James  2012    1
# 10247           LeBron James  2013    1
# 9477            Kevin Durant  2014    1
# 15104          Stephen Curry  2015    1
# 15105          Stephen Curry  2016    1
# 14244      Russell Westbrook  2017    1
# 7217            James Harden  2018    1
# 6094   Giannis Antetokounmpo  2019    1
# 6095   Giannis Antetokounmpo  2020    1
# 12416           Nikola Jokić  2021    1

# %%
DF = DF.join(temp["MVP"])
DF["MVP"] = DF["MVP"].fillna(0)
DF[DF.index.isin(index_mvps)].head(10)
# Out:
#                      Player Pos  Age   Tm   G    GS    MP    FG   FGA    FG%  \
# 385           Allen Iverson  SG   25  PHI  71  71.0  42.0  10.7  25.5  0.420
# 2471        Charles Barkley  PF   29  PHO  76  76.0  37.6   9.4  18.1  0.520
# 4006         David Robinson   C   29  SAS  81  81.0  38.0   9.7  18.4  0.530
# 4482           Derrick Rose  PG   22  CHI  81  81.0  37.4   8.8  19.7  0.445
# 4684          Dirk Nowitzki  PF   28  DAL  78  78.0  36.2   8.6  17.2  0.502
# 6094  Giannis Antetokounmpo  PF   24  MIL  72  72.0  32.8  10.0  17.3  0.578
# 6095  Giannis Antetokounmpo  PF   25  MIL  63  63.0  30.4  10.9  19.7  0.553
# 6416        Hakeem Olajuwon   C   31  HOU  80  80.0  41.0  11.2  21.2  0.528
# 7217           James Harden  SG   28  HOU  72  72.0  35.4   9.0  20.1  0.449
# 9091            Karl Malone  PF   33  UTA  82  82.0  36.6  10.5  19.2  0.550
#
#        3P   3PA    3P%    2P   2PA    2P%   eFG%   FT   FTA    FT%  ORB   DRB  \
# 385   1.4   4.3  0.320   9.4  21.2  0.441  0.447  8.2  10.1  0.814  0.7   3.1
# 2471  0.9   2.9  0.305   8.5  15.2  0.561  0.545  5.9   7.7  0.765  3.1   9.1
# 4006  0.1   0.2  0.300   9.7  18.1  0.533  0.532  8.1  10.5  0.774  2.9   7.9
# 4482  1.6   4.8  0.332   7.2  15.0  0.481  0.485  5.9   6.9  0.858  1.0   3.1
# 4684  0.9   2.2  0.416   7.7  15.0  0.515  0.529  6.4   7.1  0.904  1.6   7.3
# 6094  0.7   2.8  0.256   9.3  14.5  0.641  0.599  6.9   9.5  0.729  2.2  10.3
# 6095  1.4   4.7  0.304   9.5  15.0  0.631  0.589  6.3  10.0  0.633  2.2  11.4
# 6416  0.1   0.2  0.421  11.1  20.9  0.529  0.530  4.9   6.8  0.716  2.9   9.1
# 7217  3.7  10.0  0.367   5.4  10.1  0.531  0.541  8.7  10.1  0.858  0.6   4.8
# 9091  0.0   0.2  0.000  10.5  19.0  0.555  0.550  6.4   8.4  0.755  2.4   7.5
#
#        TRB  AST  STL  BLK  TOV   PF   PTS  Year  Pts Won  Pts Max  Share  \
# 385    3.8  4.6  2.5  0.3  3.3  2.1  31.1  2001   1121.0   1240.0  0.904
# 2471  12.2  5.1  1.6  1.0  3.1  2.6  25.6  1993    835.0    980.0  0.852
# 4006  10.8  2.9  1.7  3.2  2.9  2.8  27.6  1995    901.0   1050.0  0.858
# 4482   4.1  7.7  1.0  0.6  3.4  1.7  25.0  2011   1182.0   1210.0  0.977
# 4684   8.9  3.4  0.7  0.8  2.1  2.2  24.6  2007   1138.0   1290.0  0.882
# 6094  12.5  5.9  1.3  1.5  3.7  3.2  27.7  2019    941.0   1010.0  0.932
# 6095  13.6  5.6  1.0  1.0  3.7  3.1  29.5  2020    962.0   1010.0  0.952
# 6416  11.9  3.6  1.6  3.7  3.4  3.6  27.3  1994    889.0   1010.0  0.880
# 7217   5.4  8.8  1.8  0.7  4.4  2.3  30.4  2018    965.0   1010.0  0.955
# 9091   9.9  4.5  1.4  0.6  2.8  2.6  27.4  1997    986.0   1150.0  0.857
#
#                     Team  index   W   L   W/L%   GB   PS/G   PA/G   SRS  \
# 385   Philadelphia 76ers      0  56  26  0.683  0.0   94.7   90.4  3.64
# 2471        Phoenix Suns      8  62  20  0.756  0.0  113.4  106.7  6.27
# 4006   San Antonio Spurs      1  62  20  0.756  0.0  106.6  100.6  5.90
# 4482       Chicago Bulls      6  62  20  0.756  0.0   98.6   91.3  6.53
# 4684    Dallas Mavericks     13  67  15  0.817  0.0  100.0   92.8  7.28
# 6094     Milwaukee Bucks      6  60  22  0.732  0.0  118.1  109.3  8.04
# 6095     Milwaukee Bucks      6  56  17  0.767  0.0  118.7  108.6  9.41
# 6416     Houston Rockets      1  58  24  0.707  0.0  101.1   96.8  4.19
# 7217     Houston Rockets     13  65  17  0.793  0.0  112.4  103.9  8.21
# 9091           Utah Jazz      1  64  18  0.780  0.0  103.1   94.3  7.97
#
#       MVP_Y-1  MVP_Y-1_Y-2  MVP
# 385         0            0  1.0
# 2471        0            0  1.0
# 4006        0            0  1.0
# 4482        0            0  1.0
# 4684        0            0  1.0
# 6094        0            0  1.0
# 6095        1            0  1.0
# 6416        0            0  1.0
# 7217        0            0  1.0
# 9091        0            0  1.0

# %%
DF.sort_values(["Player","Year"],inplace = True)
DF["MVP_Y-1"] = 0 #A été MVP l'année d'avant
DF["MVP_Y-1_Y-2"] = 0#A été MVP les deux années précédentes
for i in range(2,len(DF)):
    if(DF["Player"].iloc[i]==DF["Player"].iloc[i-1] and DF["MVP"].iloc[i-1]==1):
        DF["MVP_Y-1"].iloc[i] = 1
    if(DF["Player"].iloc[i]==DF["Player"].iloc[i-1]==DF["Player"].iloc[i-2] and DF["MVP"].iloc[i-1]==DF["MVP"].iloc[i-2]==1):
        DF["MVP_Y-1_Y-2"].iloc[i] = 1

# %%
del DF["MVP"]

# %% [markdown]
# Enfin, on met à jour la base de données pour garder ces changements.

# %%
DF.to_sql("FinalStat", con = FinalStatcon,if_exists = "replace")
# Out:
# 17207

# %%
FinalStatcon.close()
