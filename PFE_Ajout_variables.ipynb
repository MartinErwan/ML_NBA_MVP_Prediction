# %%
import pandas as pd
import sqlite3
pd.options.display.max_columns = 205
import warnings
warnings.filterwarnings("ignore")

# %%
FinalStatcon = sqlite3.connect('finalstat.sqlite')

# %%
FinalStat = pd.read_sql("""SELECT * from FinalStat""", FinalStatcon)

# %%
DF = FinalStat.copy()

# %%
#Récupérations des index des MVPS de chaque année
index_mvps = DF.sort_values('Share',ascending=False).drop_duplicates('Year',keep='first').index 
DF[DF.index.isin(index_mvps)]
del DF["level_0"]

# %% [markdown]
# ## Création des colonnes "MVP l'année précédente" et "MVP deux années avant"

# %% [markdown]
# Maintenant que nous avons récupérer tous les MVPS, on peut maintenant créer nos 2 colonnes. Pour se faire, nous allons travailler sur un sous ensemble de nos données qui contient uniquement les informations qui nous intéressent dans cette partie.

# %%
temp = DF.loc[index_mvps,["Player","Year"]].sort_values("Year")
temp["MVP"] = 1

temp
# Out:
#                       Player  Year  MVP
# 5769            Moses Malone  1982    1
# 9085            Moses Malone  1983    1
# 16664             Larry Bird  1984    1
# 16675             Larry Bird  1985    1
# 13627             Larry Bird  1986    1
# 22             Magic Johnson  1987    1
# 15125         Michael Jordan  1988    1
# 48             Magic Johnson  1989    1
# 60             Magic Johnson  1990    1
# 12424         Michael Jordan  1991    1
# 12437         Michael Jordan  1992    1
# 16741        Charles Barkley  1993    1
# 16538        Hakeem Olajuwon  1994    1
# 12315         David Robinson  1995    1
# 13666         Michael Jordan  1996    1
# 1946             Karl Malone  1997    1
# 13694         Michael Jordan  1998    1
# 1973             Karl Malone  1999    1
# 213         Shaquille O'Neal  2000    1
# 1207           Allen Iverson  2001    1
# 6888              Tim Duncan  2002    1
# 16073             Tim Duncan  2003    1
# 17977          Kevin Garnett  2004    1
# 6914              Steve Nash  2005    1
# 6932              Steve Nash  2006    1
# 11991          Dirk Nowitzki  2007    1
# 8604             Kobe Bryant  2008    1
# 7306            LeBron James  2009    1
# 7324            LeBron James  2010    1
# 15872           Derrick Rose  2011    1
# 17049           LeBron James  2012    1
# 17001           LeBron James  2013    1
# 8135            Kevin Durant  2014    1
# 7835           Stephen Curry  2015    1
# 7344           Stephen Curry  2016    1
# 8189       Russell Westbrook  2017    1
# 1089            James Harden  2018    1
# 14901  Giannis Antetokounmpo  2019    1
# 16024  Giannis Antetokounmpo  2020    1
# 775             Nikola Jokić  2021    1
# 798             Nikola Jokić  2022    1
# 12563            Cody Zeller  2023    1

# %%
DF = DF.join(temp["MVP"])
DF["MVP"] = DF["MVP"].fillna(0)
DF[DF.index.isin(index_mvps)].head(10)
# Out:
#                 Player Pos  Age   Tm   G    GS    MP    FG   FGA    FG%   3P  \
# 22       Magic Johnson  PG   27  LAL  80  80.0  36.3   8.5  16.4  0.522  0.1
# 48       Magic Johnson  PG   29  LAL  77  77.0  37.5   7.5  14.8  0.509  0.8
# 60       Magic Johnson  PG   30  LAL  79  79.0  37.2   6.9  14.4  0.480  1.3
# 213   Shaquille O'Neal   C   27  LAL  79  79.0  40.0  12.1  21.1  0.574  0.0
# 775       Nikola Jokić   C   25  DEN  72  72.0  34.6  10.2  18.0  0.566  1.3
# 798       Nikola Jokić   C   26  DEN  74  74.0  33.5  10.3  17.7  0.583  1.3
# 1089      James Harden  SG   28  HOU  72  72.0  35.4   9.0  20.1  0.449  3.7
# 1207     Allen Iverson  SG   25  PHI  71  71.0  42.0  10.7  25.5  0.420  1.4
# 1946       Karl Malone  PF   33  UTA  82  82.0  36.6  10.5  19.2  0.550  0.0
# 1973       Karl Malone  PF   35  UTA  49  49.0  37.4   8.0  16.3  0.493  0.0
#
#        3PA    3P%    2P   2PA    2P%   eFG%   FT   FTA    FT%  ORB   DRB  \
# 22     0.5  0.205   8.4  15.9  0.532  0.525  6.7   7.9  0.848  1.5   4.8
# 48     2.4  0.314   6.8  12.3  0.548  0.535  6.7   7.3  0.911  1.4   6.4
# 60     3.5  0.384   5.6  10.9  0.510  0.526  7.2   8.1  0.890  1.6   5.0
# 213    0.0  0.000  12.1  21.1  0.575  0.574  5.5  10.4  0.524  4.3   9.4
# 775    3.3  0.388   8.9  14.7  0.606  0.602  4.8   5.5  0.868  2.8   8.0
# 798    3.9  0.337   9.0  13.8  0.652  0.620  5.1   6.3  0.810  2.8  11.0
# 1089  10.0  0.367   5.4  10.1  0.531  0.541  8.7  10.1  0.858  0.6   4.8
# 1207   4.3  0.320   9.4  21.2  0.441  0.447  8.2  10.1  0.814  0.7   3.1
# 1946   0.2  0.000  10.5  19.0  0.555  0.550  6.4   8.4  0.755  2.4   7.5
# 1973   0.0  0.000   8.0  16.2  0.494  0.493  7.7   9.8  0.788  2.2   7.3
#
#        TRB   AST  STL  BLK  TOV   PF   PTS  Year  Pts Won  Pts Max  Share  \
# 22     6.3  12.2  1.7  0.5  3.8  2.1  23.9  1987    733.0    780.0  0.940
# 48     7.9  12.8  1.8  0.3  4.1  2.2  22.5  1989    664.5    850.0  0.782
# 60     6.6  11.5  1.7  0.4  3.7  2.1  22.3  1990    636.0    920.0  0.691
# 213   13.6   3.8  0.5  3.0  2.8  3.2  29.7  2000   1207.0   1210.0  0.998
# 775   10.8   8.3  1.3  0.7  3.1  2.7  26.4  2021    971.0   1010.0  0.961
# 798   13.8   7.9  1.5  0.9  3.8  2.6  27.1  2022    875.0   1000.0  0.875
# 1089   5.4   8.8  1.8  0.7  4.4  2.3  30.4  2018    965.0   1010.0  0.955
# 1207   3.8   4.6  2.5  0.3  3.3  2.1  31.1  2001   1121.0   1240.0  0.904
# 1946   9.9   4.5  1.4  0.6  2.8  2.6  27.4  1997    986.0   1150.0  0.857
# 1973   9.4   4.1  1.3  0.6  3.3  2.7  23.8  1999    827.0   1180.0  0.701
#
#                     Team  index   W   L   W/L%   GB   PS/G   PA/G   SRS  MVP
# 22    Los Angeles Lakers      8  65  17  0.793  0.0  117.8  108.5  8.32  1.0
# 48    Los Angeles Lakers      8  57  25  0.695  0.0  114.7  107.5  6.38  1.0
# 60    Los Angeles Lakers      9  63  19  0.768  0.0  110.7  103.9  6.74  1.0
# 213   Los Angeles Lakers      9  67  15  0.817  0.0  100.8   92.3  8.41  1.0
# 775       Denver Nuggets      2  47  25  0.653  5.0  115.1  110.1  4.82  1.0
# 798       Denver Nuggets      2  48  34  0.585  1.0  112.7  110.4  2.16  1.0
# 1089     Houston Rockets     13  65  17  0.793  0.0  112.4  103.9  8.21  1.0
# 1207  Philadelphia 76ers      0  56  26  0.683  0.0   94.7   90.4  3.64  1.0
# 1946           Utah Jazz      1  64  18  0.780  0.0  103.1   94.3  7.97  1.0
# 1973           Utah Jazz      2  37  13  0.740  0.0   93.3   86.8  5.54  1.0

# %%
DF.sort_values(["Player","Year"],inplace = True)
DF["MVP_Y-1"] = 0 #A été MVP l'année d'avant
DF["MVP_Y-1_Y-2"] = 0#A été MVP les deux années précédentes
for i in range(2,len(DF)):
    if(DF["Player"].iloc[i]==DF["Player"].iloc[i-1] and DF["MVP"].iloc[i-1]==1):
        DF["MVP_Y-1"].iloc[i] = 1
    if(DF["Player"].iloc[i]==DF["Player"].iloc[i-1]==DF["Player"].iloc[i-2] and DF["MVP"].iloc[i-1]==DF["MVP"].iloc[i-2]==1):
        DF["MVP_Y-1_Y-2"].iloc[i] = 1

# %%
del DF["MVP"]

# %% [markdown]
# Enfin, on met à jour la base de données pour garder ces changements.

# %%
DF.to_sql("FinalStat", con = FinalStatcon,if_exists = "replace")
# Out:
# 18352

# %%
FinalStatcon.close()
